# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![ejercicios.png](attachment:ejercicios.png)

# %% [markdown]
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomesticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas ultimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
# * Método que calcula la media de ventas de los ultimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
# 1. Creamos una clase Tienda
class Tienda:
# Caracteristicas comunes
    Tipo = "Electrodomesticos"
    Abierta = True
# Constructor con caracteristicas: Nombre, Dirección, Número de empleados y Ventas de los últimos 3 meses en una lista
    def __init__ (self, nombre, direccion, num_empleados, ventas_3meses):
        self.nombre = nombre
        self.direccion = direccion
        self.num_empleados = num_empleados
        self.ventas_3meses = ventas_3meses

# Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
    def ventas_totales (self):
        self.ventas_3meses = [int (i) for i in self.ventas_3meses]
        return sum (self.ventas_3meses)

# Método que calcula la media de ventas de los ultimos meses, por empleado.
    def ventas_por_empleado (self):
        self.num_empleados = int (self.num_empleados)
        return self.ventas_totales () / self.num_empleados

# Método que devuelve en un string el nombre de la tienda, junto con su dirección.
    def nombre_direccion (self):
        return self.nombre + "_" + self.direccion

# Método que obtiene las ventas del último mes.
    def ventas_ultimo_mes (self):
        return int (self.ventas_3meses [-1])

# Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda.
    def proyeccion_ventas (self, inversion):
        if inversion < 1000:
            self.ventas_3meses = [i * 1.2 for i in self.ventas_3meses]
            return self.ventas_3meses
        else:
            self.ventas_3meses = [i * 1.5 for i in self.ventas_3meses]
            return self.ventas_3meses

# %%
# 2. Crear tres tiendas con datos inventados.
Tienda1 = Tienda ("Tien21", "Autonomia 52", 6, [20000, 22000, 21000])
Tienda2 = Tienda ("Worten", "Avenida Ferrocarril 2", 8, [25000, 26000, 28000])
Tienda3 = Tienda ("Expert", "Plaza Moyua 20", 4, [18000, 17000, 20000])

# %%
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
print (Tienda1.nombre)
print (Tienda1.direccion)
print (Tienda1.num_empleados)
print (Tienda1.ventas_3meses)
print (Tienda1.ventas_totales())
print (Tienda1.ventas_por_empleado())
print (Tienda1.nombre_direccion ())
print (Tienda1.ventas_ultimo_mes ())
print (Tienda1.proyeccion_ventas (1050))
# Out:
# Tien21
# Autonomia 52
# 6
# [20000, 22000, 21000]
# 63000
# 10500.0
# Tien21_Autonomia 52
# 21000
# [30000.0, 33000.0, 31500.0]

# %%
# 4. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle for
total_ventas_ultimo_mes = 0
for tienda in [Tienda1, Tienda2, Tienda3]:
    total_ventas_ultimo_mes += tienda.ventas_ultimo_mes()
    # print(tienda.ventas_ultimo_mes())
print ("Las ventas del último mes de todas las tiendas son: ", total_ventas_ultimo_mes)
# Out:
# Las ventas del último mes de todas las tiendas son:  69000

# %%
# 5. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
for tienda in [Tienda1, Tienda2, Tienda3]:
    if "Avenida" in tienda.direccion:
        print ('la tienda cuya dirección lleva la palabra "Avenida" es: ', tienda.nombre)
# Out:
# la tienda cuya dirección lleva la palabra "Avenida" es:  Worten

# %%
# 6. Seguro que ya has hecho este apartado... Documenta la clase :)

class Tienda:
    # Docstring
    """
    Definimos una clase con Nombre: "Tienda" que tiene los siguientes atributos:

    Atributos comunes:
    Tipo: "Electrodomésticos"
    Abierta: True

    Atributos propios a introducir para cada tienda:
    Nombre: String
    Dirección: String
    Número de empleados: int
    Ventas ultimos 3 meses: Lista de 3 numeros

    Definiremos los siguientes métodos:
    Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
    Método que calcula la media de ventas de los ultimos meses, por empleado
    Método que devuelve en un string el nombre de la tienda, junto con su dirección.
    Método que obtiene las ventas del último mes.
    Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda.
    Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas),
    si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses,
    y además devuelve las ventas con el aumento.Clase que representa una tienda de electrodomésticos

    """
# Caracteristicas comunes
    Tipo = "Electrodomesticos"
    Abierta = True
# Constructor con caracteristicas: Nombre, Dirección, Número de empleados y Ventas de los últimos 3 meses en una lista
    def __init__ (self, nombre, direccion, num_empleados, ventas_3meses):
        self.nombre = nombre
        self.direccion = direccion
        self.num_empleados = num_empleados
        self.ventas_3meses = ventas_3meses

# Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
    def ventas_totales (self):
        """ El método ventas_totales calcula las ventas de todos los meses y devuelve un numero con todas las ventas  """
        self.ventas_3meses = [int (i) for i in self.ventas_3meses]
        return sum (self.ventas_3meses)

# Método que calcula la media de ventas de los ultimos meses, por empleado.
    def ventas_por_empleado (self):
        """ El método ventas_por_empleado cálcula la media de ventas de los ultimos meses, por número de empleados """
        self.num_empleados = int (self.num_empleados)
        return self.ventas_totales () / self.num_empleados

# Método que devuelve en un string el nombre de la tienda, junto con su dirección.
    def nombre_direccion (self):
        """ El método nombre_direccion devuelve en un string el nombre de la tienda, junto con la dirección """
        return self.nombre + "_" + self.direccion

# Método que obtiene las ventas del último mes.
    def ventas_ultimo_mes (self):
        """ El método ventas_ultimo_mes devuelve las ventas del último mes """
        return int (self.ventas_3meses [-1])

# Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda.
    def proyeccion_ventas (self, inversion):
        """ El método proyeccion_ventas cálcula una proyección de las ventas en caso de haber invertido x dinero en marketing en esa tienda.
        Siendo x el parámetro de entrada. Si x es menor de 1000, las ventas de los ultimos 3 meses hubiesen sído de (1.2 x ventas),
        si es mayor o igual de 1000, las ventas hubiesen sído de (1.5 x ventas). El método reescribe el atributo de ventas en los últimos 3 meses y
        además devuelve las ventas con el aumento. """
        if inversion < 1000:
            self.ventas_3meses = [i * 1.2 for i in self.ventas_3meses]
            return self.ventas_3meses
        else:
            self.ventas_3meses = [i * 1.5 for i in self.ventas_3meses]
            return self.ventas_3meses

print (Tienda.__doc__)
print ("\n- - - - - - - - - - - - - - -  - - - \n")
print (Tienda.ventas_totales.__doc__)
print ("\n- - - - - - - - - - - - - - - - - - - \n")
help (Tienda)
# Out:
#     Definimos una clase con Nombre: "Tienda" que tiene los siguientes atributos:
#
#     Atributos comunes:
#     Tipo: "Electrodomésticos"
#     Abierta: True
#
#     Atributos propios a introducir para cada tienda:
#     Nombre: String
#     Dirección: String
#     Número de empleados: int
#     Ventas ultimos 3 meses: Lista de 3 numeros
#
#     Definiremos los siguientes métodos:
#     Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
#     Método que calcula la media de ventas de los ultimos meses, por empleado
#     Método que devuelve en un string el nombre de la tienda, junto con su dirección.
#     Método que obtiene las ventas del último mes.
#     Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda.
#     Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas),
# ...

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
class Perro:
    """
    Vamos a implementar una clase Perro. La clase tiene las siguientes características:
    Tiene 4 patas
    2 orejas
    2 ojos
    Una velocidad de 0. Por defecto, el perro está parado

    Cuando se inicialice:
    El perro será de una determinada raza
    Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
    Por defecto no tendrá dueño, a no ser que se diga lo contrario.

    Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad).
    Este valor se le sumará a la velocidad que ya llevaba el perro.

    Necesita otro método (parar), donde pondremos la velocidad a 0.

    Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
    """
    patas = 4
    orejas = 2
    ojos = 2
    #velocidad = 0

    def __init__ (self, raza, pelo = "marron", dueño = None ):
        """
        Inicializados la clase Perro con los siguientes atributos:
        El perro será de una determinada raza
        Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
        Por defecto no tendrá dueño, a no ser que se diga lo contrario.
        """
        self.raza = raza
        self.pelo = pelo
        self.dueño = dueño
        self.velocidad = 0

    def andar (self, aumento_velocidad):
        """
        El método andar tiene un argumento de entrada (aumento_velocidad)
        Este valor se le sumará a la velocidad que ya llevaba el perro y nos dará la velocidad final.
        """
        self.velocidad += aumento_velocidad
        print ("La velocidad del perro es:", self.velocidad)

    def parar (self):
        """
        El método parar nos pondrá la velocidad a 0
        """
        self.velocidad = 0
        print ("El perro se ha parado. La velocidad del perro es: ", self.velocidad)

    def ladrar (self, argumento):
        """
        El método ladrar tendrá un argumento de entrada y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
        """
        print ("GUAU!" + argumento)

# %%
# Creamos una clase Perro, sin dueño
Perro1 = Perro ("Pastor alemán")

# %%
# Comprobamos sus atributos
print ("La raza de nuestro perro es: ", Perro1.raza)
print ("El perro tiene color de pelo: ", Perro1.pelo)
print ("El perro no tiene dueño: ", Perro1.dueño)
# Out:
# La raza de nuestro perro es:  Pastor alemán
# El perro tiene color de pelo:  marron
# El perro no tiene dueño:  None

# %%
# Probamos que nuestro perro anda y comprobamos su velocidad
Perro1.andar (3)
# Out:
# La velocidad del perro es: 3

# %%
# Paramos a nuestro perro y comprobamos su velocidad
Perro1.parar ()
# Out:
# El perro se ha parado. La velocidad del perro es:  0

# %%
# Comprobamos que nuestro perro ladra
Perro1.ladrar (" Nuestro perro está contento")
# Out:
# GUAU! Nuestro perro está contento

# %%
# Documentamos la clase Perro
print (Perro. __doc__)
print ("\n- - - - - - - - - - - - - - - - - - - - - - - \n")
help (Perro)
# Out:
#     Vamos a implementar una clase Perro. La clase tiene las siguientes características:
#     Tiene 4 patas
#     2 orejas
#     2 ojos
#     Una velocidad de 0. Por defecto, el perro está parado
#
#     Cuando se inicialice:
#     El perro será de una determinada raza
#     Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
#     Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad).
#     Este valor se le sumará a la velocidad que ya llevaba el perro.
#
#     Necesita otro método (parar), donde pondremos la velocidad a 0.
#
#     Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# - - - - - - - - - - - - - - - - - - - - - - -
#
# Help on class Perro in module __main__:
#
# class Perro(builtins.object)
#  |  Perro(raza, pelo='marron', dueño=None)
#  |
# ...
